# %% [markdown]
# <a href="https://colab.research.google.com/github/WagnerLopesCardozo/Projetos-de-Estudo-CD-FaTec-Ourinhos/blob/main/Merge_Sort_Teste_do_M%C3%A9todo_de_Ordena%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Definição Tamanho(n)

#[100, 1000, 5000, 10000, 20000, 50000, 100000, 200000, 500000 ]

import random
import numpy as np
n = 1000000
X = list(np.random.random(n))

#print(X) # para testar com poucos elementos e poder observar a criação
print()
print('Vetor não ordenado de tamanho', len(X), 'realizado com sucesso!')
# Out:
# Vetor não ordenado de tamanho 1000000 realizado com sucesso!

# %%
# Implementação em Python do algoritmo de ordenação MergeSort (comum a todos)

import time
import random
import numpy as np

def MergeSort(L):

  if len(L) > 1:
    meio = len(L)//2
    LE = L[:meio] # Lista Esquerda
    LD = L[meio:] # Lista Direita
    # Aplica recursivamente nas sublistas
    MergeSort(LE)
    MergeSort(LD)
    # Quando volta da recursão inicia aqui!
    i, j, k = 0, 0, 0
    # Faz a intercalação das duas listas (merge)
    while i < len(LE) and j < len(LD):
        if LE[i] < LD[j]:
            L[k] = LE[i]
            i += 1
        else:
            L[k] = LD[j]
            j += 1
        k += 1
    while i < len(LE):
        L[k] = LE[i]
        i += 1
        k += 1
    while j < len(LD):
        L[k] = LD[j]
        j += 1
        k += 1

# Aplica MergSort
inicio = time.time()
MergeSort(X)
fim = time.time()

print('Método aplicado: MergSort')
print()
print('Tamanho do vetor:', n)
#print('Vetor ordenado: ')
#print(X)
print()
print('Tempo de processamento: %.3f s' %(fim - inicio))
# Out:
# Método aplicado: MergSort
#
# Tamanho do vetor: 1000000
#
# Tempo de processamento: 8.572 s

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot


#L = [100, 1000, 5000, 10000, 20000, 50000, 100000, 200000, 500000 ]

L = [100, 1000, 5000, 10000, 20000, 50000, 100000]


#MergeSort  
t1 = [ 1, 2, 3, 4, 5, 6, 7 ]

#QuickSort
t2 = [ 2, 4, 6, 8, 10, 12, 14]

#ShellSort
t3 = [ 3, 6, 9, 12, 15, 18, 21 ]

#BucketSort
t4 = [ 4, 8, 12, 16, 20, 24, 28]

#Selectionsort
t5 = [ 5, 10, 15, 20, 25, 30, 35 ]

#BozoSort
t6 = [ 6, 12, 18, 24, 30, 36, 42 ]

#RadixSort
t7 = [ 7, 14, 21, 28, 35, 42, 49]

plt.title("Gráfico comparativo Métodos de Ordenação")
plt.xlabel("Elementos")
plt.ylabel("Tempo(s)")

plt.plot(L, t1)
plt.plot(L, t2)
plt.plot(L, t3)
plt.plot(L, t4)
plt.plot(L, t5)
plt.plot(L, t6)
plt.plot(L, t7)

pyplot.plot(L, t1, label='MergeSort')
pyplot.plot(L, t2, label='QuickSort')
pyplot.plot(L, t3, label='ShellSort')
pyplot.plot(L, t4, label='BucketSort')
pyplot.plot(L, t5, label='SelectionSort')
pyplot.plot(L, t6, label='BozoSort')
pyplot.plot(L, t7, label='RadizSort')
pyplot.legend()
plt.show()
